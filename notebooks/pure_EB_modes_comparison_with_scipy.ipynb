# %% [markdown]
# # Comparison with Scipy
#
# In this notebook we are comparing the results with `Scipy`. It is difficult to have strictly the same interpolation function so we are using [`CubicSpline`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.CubicSpline.html) which lead to very similar results compare to the function used in `cosmo-numba`. On the other hand, the integration should be performed using the same functions from `QUADPACK` under the hood.

# %%
import pyccl as ccl
import matplotlib.pyplot as plt
import numpy as np

# %%
from cosmo_numba.B_modes.schneider2022 import get_pure_EB_modes

# %%
from pure_EB_sc import get_pure_EB_modes as get_pure_EB_modes_sc

# %%
import matplotlib as mpl

mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.markersize'] = 6

mpl.rcParams['font.size'] = 13

mpl.rcParams['xtick.minor.size'] = 5
mpl.rcParams['ytick.minor.size'] = 5
mpl.rcParams['xtick.major.size'] = 7
mpl.rcParams['ytick.major.size'] = 7


mpl.rcParams['xtick.minor.width'] = 1
mpl.rcParams['ytick.minor.width'] = 1
mpl.rcParams['xtick.major.width'] = 1
mpl.rcParams['ytick.major.width'] = 1


# mpl.rcParams['axes.xmargin'] = mpl.rcParamsDefault['axes.xmargin']

color = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# ## Cosmo model

# %%
def get_model(
    theta,
    z,
    nz,
    Omega_c,
    h,
    Omega_b,
    sig8,
    ns,
    B_amp,
    b_ia,
    l_min=None,
    l_max=None,
    ell=None,
):

    theta_deg = theta/60

    cosmo = ccl.Cosmology(
        Omega_c=Omega_c,
        Omega_b=Omega_b,
        h=h,
        n_s=ns,
        sigma8=sig8,

        transfer_function='boltzmann_camb',
        matter_power_spectrum='camb',
        extra_parameters={
            "camb": {
                "halofit_version": 'mead2016',
                "HMCode_A_baryon": B_amp,
                "kmax": 21,
                # We do this to avoid warnings in CAMB with (kmax < 5 or
                # 'kmax < 20 and z > 4') (set internally in ccl)
                # default: kmax=10
            }
        }
    )
    ccl.gsl_params.LENSING_KERNEL_SPLINE_INTEGRATION = True

    lens = ccl.WeakLensingTracer(
        cosmo,
        dndz=(z, nz),
        ia_bias=(z, np.ones_like(z)*b_ia),
        use_A_ia=True,
    )

    if ell is None:
        if l_min is None and l_max is None:
            l_min = 1
            l_max = 100_000
        l_bin = (l_max - l_min) + 1
        ell = np.logspace(np.log10(l_min), np.log10(l_max), l_bin)
    cl = ccl.angular_cl(cosmo, lens, lens, ell)

    xip_fit = ccl.correlation(
        cosmo,
        ell=ell,
        C_ell=cl,
        theta=theta_deg,
        type='GG+',
        method='fftlog',
    )
    xim_fit = ccl.correlation(
        cosmo,
        ell=ell,
        C_ell=cl,
        theta=theta_deg,
        type='GG-',
        method='fftlog'
    )

    return xip_fit, xim_fit, ell, cl

# %%
def smail_nz(z, z0, alpha, beta):
    """
    """
    return (z / z0) ** beta * np.exp(-(z / z0) ** alpha)

# %% [markdown]
# ## Set parameters

# %%
# Thin bins
tmin_int = 0.5
tmax_int = 800
bin_size_int = 0.02
#nbins_int = int((np.log(tmax_int) - np.log(tmin_int))/bin_size_int)
nbins_int = 1_000
print("nbins int:", nbins_int)

tmin = 0.5
tmax = 250
bin_size = 0.3
nbins = int((np.log(tmax) - np.log(tmin))/bin_size)
print("nbins:", nbins)
# Out:
# nbins int: 1000
# nbins: 20

# %%
# Planck cosmo 2018 | TT,TE,EE+lowE+lensing+BAO
h = 0.6766
Om = 0.3111
Ov = 0.6889
sig8 = 0.8102
ns = 0.9665
Ob_h2 = 0.02242
Ob = Ob_h2/h**2
Oc_h2 = 0.11933
Oc = Oc_h2/h**2
b_ia = 0.5
B_amp = 3.13

area = 14_300
shape_noise = 0.26
n_eff = 27

alpha_nz = 0.68
beta_nz = 2.
z0_nz = 0.13
z = np.linspace(0, 4, 256)
nz = smail_nz(z, z0_nz, alpha_nz, beta_nz)

# %% [markdown]
# ## Get pure B-modes

# %%
theta_ = np.logspace(np.log10(tmin), np.log10(tmax), nbins+1)
theta = np.mean([theta_[:-1], theta_[1:]], axis=0)
theta_int_ = np.logspace(np.log10(tmin_int), np.log10(tmax_int), nbins_int+1)
theta_int = np.mean([theta_int_[:-1], theta_int_[1:]], axis=0)

# %%
xip_model_int, xim_model_int, _, _ = get_model(
    theta_int,
    z,
    nz,
    Oc,
    h,
    Ob,
    sig8,
    ns,
    B_amp,
    b_ia,
)

# %%
xip_model, xim_model, _, _ = get_model(
    theta,
    z,
    nz,
    Oc,
    h,
    Ob,
    sig8,
    ns,
    B_amp,
    b_ia,
)

# %%
plt.plot(theta, xip_model, label="fiducial")
plt.plot(theta_int, xip_model_int, "--", label="for integration")
plt.xscale("log")
plt.yscale("log")
plt.xlabel(r"$\theta$ [arcmin]")
plt.ylabel(r"$\xi_+(\theta)$")
plt.legend()
plt.title("Shear two-point correlation function model")
plt.grid()
plt.show()

# %%
xip_E_model, xim_E_model, xip_B_model, xim_B_model, xip_amb_model, xim_amb_model = get_pure_EB_modes(
    theta, xip_model, xim_model, theta_int, xip_model_int, xim_model_int, np.min(theta), np.max(theta), parallel=True, pad_xim=True,
    interp_order=5,
)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
xip_E_model_np, xim_E_model_np, xip_B_model_np, xim_B_model_np, xip_amb_model_np, xim_amb_model_np = get_pure_EB_modes(
    theta, xip_model, xim_model, theta_int, xip_model_int, xim_model_int, np.min(theta), np.max(theta), parallel=True, pad_xim=False,
)

# %%
xip_E_model_sc, xim_E_model_sc, xip_B_model_sc, xim_B_model_sc, xip_amb_model_sc, xim_amb_model_sc = get_pure_EB_modes_sc(
    theta, xip_model, xim_model, theta_int, xip_model_int, xim_model_int, np.min(theta), np.max(theta), parallel=False, pad_xim=True,
)
# Out:
# /Users/aguinot/Documents/cosmo-numba/notebooks/pure_EB_sc.py:71: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   res = quad(
# /Users/aguinot/Documents/cosmo-numba/notebooks/pure_EB_sc.py:71: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   res = quad(

# %%
plt.plot(theta, theta*xip_E_model_sc/1e-4, '-', color=color[0], label=r"$\xi_{+}^{E}$ scipy")
plt.plot(theta, theta*xip_E_model/1e-4, '-.', color=color[1], label=r"$\xi_{+}^{E}$ numba")
plt.xscale('log')
plt.legend()

# %%
plt.plot(theta, theta*xip_B_model_sc/1e-4, '-', color=color[0], label=r"$\xi_{+}^{B}$ scipy")
plt.plot(theta, theta*xip_B_model/1e-4, '-.', color=color[1], label=r"$\xi_{+}^{B}$ numba")
plt.xscale('log')
plt.legend()

# %%
plt.plot(theta, xip_E_model_sc-xip_E_model, '-', color=color[0], label=r"$\xi_{+}^{E}$")
plt.plot(theta, xim_E_model_sc-xim_E_model, '-', color=color[1], label=r"$\xi_{-}^{E}$")
plt.xscale('log')
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\xi_{\pm}^{E,\rm{scipy}}-\xi_{\pm}^{E,\rm{numba}}$")
plt.legend()

# %%
plt.plot(theta, xip_B_model_sc-xip_B_model, '-', color=color[0], label=r"$\xi_{+}^{B}$")
plt.plot(theta, xim_B_model_sc-xim_B_model, '-', color=color[1], label=r"$\xi_{-}^{B}$")
plt.xscale('log')
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\xi_{\pm}^{B,\rm{scipy}}-\xi_{\pm}^{B,\rm{numba}}$")
plt.legend()

# %%
# %%timeit
xip_E_model, xim_E_model, xip_B_model, xim_B_model, xip_amb_model, xim_amb_model = get_pure_EB_modes(
    theta, xip_model, xim_model, theta_int, xip_model_int, xim_model_int, tmin, tmax, parallel=False,
    interp_order=3,
)
# Out:
# 118 ms ± 2.57 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
xip_E_model, xim_E_model, xip_B_model, xim_B_model, xip_amb_model, xim_amb_model = get_pure_EB_modes(
    theta, xip_model, xim_model, theta_int, xip_model_int, xim_model_int, tmin, tmax, parallel=True,
    interp_order=3,
)
# Out:
# 16.9 ms ± 313 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
xip_E_model_sc, xim_E_model_sc, xip_B_model_sc, xim_B_model_sc, xip_amb_model_sc, xim_amb_model_sc = get_pure_EB_modes_sc(
    theta, xip_model, xim_model, theta_int, xip_model_int, xim_model_int, np.min(theta), np.max(theta), parallel=False, pad_xim=True,
)
# Out:
# /Users/aguinot/Documents/cosmo-numba/notebooks/pure_EB_sc.py:71: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   res = quad(
# /Users/aguinot/Documents/cosmo-numba/notebooks/pure_EB_sc.py:71: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   res = quad(
# 1.04 s ± 16.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
